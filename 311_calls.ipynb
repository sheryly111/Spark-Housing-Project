# %% [markdown]
# # 311 Calls Database
#
# This notebook looks at datasets of 311 calls from the years 2018-2024. First, it adds a "year" column to each dataset, before merging them all into one big 311 calls dataset to be used.

# %%
import pandas as pd 
import glob 

'''
path = './311_calls/'  
all_files = glob.glob(path + "/*.csv")

combined_df = pd.concat(map(pd.read_csv, all_files), ignore_index=True)

combined_df.to_csv("raw_311_calls.csv", index=False)
'''
# Out:
# '\npath = \'./311_calls/\'  \nall_files = glob.glob(path + "/*.csv")\n\ncombined_df = pd.concat(map(pd.read_csv, all_files), ignore_index=True)\n\ncombined_df.to_csv("raw_311_calls.csv", index=False)\n'

# %%
df = pd.read_csv("raw_311_calls.csv")

df.head()
# Out:
# C:\Users\shery\AppData\Local\Temp\ipykernel_29076\1134694614.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("raw_311_calls.csv")
#    _id  case_enquiry_id              open_dt        sla_target_dt  \
# 0  1.0     101002296888  2018-01-01 00:02:00                  NaN
# 1  2.0     101002296890  2018-01-01 00:46:00  2018-01-02 03:30:00
# 2  3.0     101002296891  2018-01-01 01:08:00                  NaN
# 3  4.0     101002296892  2018-01-01 01:11:26  2018-01-03 03:30:00
# 4  5.0     101002296894  2018-01-01 01:13:00                  NaN
#
#              closed_dt on_time case_status  \
# 0  2018-01-02 08:05:36  ONTIME      Closed
# 1  2018-01-01 01:44:28  ONTIME      Closed
# 2  2018-02-05 06:03:35  ONTIME      Closed
# 3  2018-01-01 02:27:44  ONTIME      Closed
# 4  2018-02-23 05:01:35  ONTIME      Closed
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : 2018-01-02 13:05:36...
# 1  Case Closed. Closed date : 2018-01-01 06:44:28...
# 2  Case Closed. Closed date : 2018-02-05 11:03:35...
# 3  Case Closed. Closed date : 2018-01-01 07:27:44...
# 4  Case Closed. Closed date : 2018-02-23 10:01:35...
#
#                                        case_title  \
# 0  Request for Snow Plowing (Emergency Responder)
# 1                        Street Light Knock Downs
# 2                                 General Request
# 3                        Request for Snow Plowing
# 4                                    BWSC Pothole
#
#                            subject  ...      neighborhood  \
# 0          Public Works Department  ...     Jamaica Plain
# 1          Public Works Department  ...  Greater Mattapan
# 2  Boston Water & Sewer Commission  ...       East Boston
# 3          Public Works Department  ...        Dorchester
# 4  Boston Water & Sewer Commission  ...            Boston
#
#   neighborhood_services_district     ward precinct  \
# 0                             10  Ward 19     1912
# 1                             13       12     1207
# 2                              1   Ward 1     0106
# 3                              7  Ward 13     1309
# 4                              3       03     0305
#
#                       location_street_name location_zipcode   latitude  \
# 0                    340-342 Hyde Park Ave           2131.0  42.289290
# 1  INTERSECTION Franklin Park Rd & Glen Ln              NaN  42.302241
# 2                            134 Marion St           2128.0  42.376919
# 3                      1080 Dorchester Ave           2125.0  42.313820
# 4                            125 Nashua St           2114.0  42.367830
#
#    longitude                                          geom_4326  \
# 0 -71.117981  0101000020E61000009C9C12FF8CC751C0E48E1F710725...
# 1 -71.087378  0101000020E6100000927F5D9A97C551C050BAADD1AF26...
# 2 -71.036240  0101000020E6100000DBA711C351C251C00F1ADAE53E30...
# 3 -71.056851  0101000020E6100000A2B77570A3C351C02CFEF23C2B28...
# 4 -71.064950  0101000020E610000080D0E42528C451C0A918B809152F...
#
#                  source
# 0      Constituent Call
# 1      Constituent Call
# 2      Constituent Call
# 3  Citizens Connect App
# 4      Constituent Call
#
# [5 rows x 31 columns]

# %%
columns_to_remove = ["submitted_photo", "closed_photo", "latitude", "longitude", "geom_4326", "source", "fire_district", "city_council_district", "police_district", "precinct", "location_street_name", "location_zipcode"] 

df = df.drop(columns=columns_to_remove)

df.head()
# Out:
#    _id  case_enquiry_id              open_dt        sla_target_dt  \
# 0  1.0     101002296888  2018-01-01 00:02:00                  NaN
# 1  2.0     101002296890  2018-01-01 00:46:00  2018-01-02 03:30:00
# 2  3.0     101002296891  2018-01-01 01:08:00                  NaN
# 3  4.0     101002296892  2018-01-01 01:11:26  2018-01-03 03:30:00
# 4  5.0     101002296894  2018-01-01 01:13:00                  NaN
#
#              closed_dt on_time case_status  \
# 0  2018-01-02 08:05:36  ONTIME      Closed
# 1  2018-01-01 01:44:28  ONTIME      Closed
# 2  2018-02-05 06:03:35  ONTIME      Closed
# 3  2018-01-01 02:27:44  ONTIME      Closed
# 4  2018-02-23 05:01:35  ONTIME      Closed
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : 2018-01-02 13:05:36...
# 1  Case Closed. Closed date : 2018-01-01 06:44:28...
# 2  Case Closed. Closed date : 2018-02-05 11:03:35...
# 3  Case Closed. Closed date : 2018-01-01 07:27:44...
# 4  Case Closed. Closed date : 2018-02-23 10:01:35...
#
#                                        case_title  \
# 0  Request for Snow Plowing (Emergency Responder)
# 1                        Street Light Knock Downs
# 2                                 General Request
# 3                        Request for Snow Plowing
# 4                                    BWSC Pothole
#
#                            subject                             reason  \
# 0          Public Works Department                    Street Cleaning
# 1          Public Works Department                      Street Lights
# 2  Boston Water & Sewer Commission  Administrative & General Requests
# 3          Public Works Department                    Street Cleaning
# 4  Boston Water & Sewer Commission                            Pothole
#
#                                              type  \
# 0  Request for Snow Plowing (Emergency Responder)
# 1                        Street Light Knock Downs
# 2                            BWSC General Request
# 3                        Request for Snow Plowing
# 4                                    BWSC Pothole
#
#                                 queue department  \
# 0     PWDx_District 02: Jamaica Plain       PWDx
# 1       PWDx_Street Light Knock Downs       PWDx
# 2                      BWSC_All Cases       BWSC
# 3  PWDx_District 03: North Dorchester       PWDx
# 4                        BWSC_Pothole       BWSC
#
#                                             location pwd_district  \
# 0       340-342 Hyde Park Ave  Roslindale  MA  02131           02
# 1  INTERSECTION of Franklin Park Rd & Glen Ln  Ja...           02
# 2              134 Marion St  East Boston  MA  02128           09
# 3         1080 Dorchester Ave  Dorchester  MA  02125           03
# 4                   125 Nashua St  Boston  MA  02114           1B
#
#        neighborhood neighborhood_services_district     ward
# 0     Jamaica Plain                             10  Ward 19
# 1  Greater Mattapan                             13       12
# 2       East Boston                              1   Ward 1
# 3        Dorchester                              7  Ward 13
# 4            Boston                              3       03

# %%
df.to_csv("cleaned_311_calls.csv", index=False)
