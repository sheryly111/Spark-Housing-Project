# %% [markdown]
# # Building and Property Violations
# This notebook is used to clean the dataset of building and property violations: https://data.boston.gov/dataset/building-and-property-violations1/resource/800a2663-1d6a-46e7-9356-bedb70f5332c
#
# Our goal is to gather violations from the years 2018-2024.

# %%
import pandas as pd 

df = pd.read_csv("building_property_violations.csv")

df.head()
# Out:
#    _id  case_no  ap_case_defn_key          status_dttm  status   code  value  \
# 0    1   V91983              1013                  NaN  Closed  121.2    NaN
# 1    2  V876069              1013  2025-12-04 15:48:22    Open  102.8    NaN
# 2    3  V876068              1013  2025-12-04 15:27:46    Open  102.8    NaN
# 3    4  V876066              1013  2025-12-04 15:04:58    Open  102.8    NaN
# 4    5  V876048              1013  2025-12-04 14:09:47    Open    116    NaN
#
#             description violation_stno violation_sthigh  ... ward  \
# 0  Unsafe and Dangerous            302              NaN  ...   01
# 1           Maintenance             46              NaN  ...   15
# 2           Maintenance             70              NaN  ...   18
# 3           Maintenance            633              NaN  ...   07
# 4     Unsafe Structures             74              NaN  ...   18
#
#           contact_addr1 contact_addr2 contact_city contact_state contact_zip  \
# 0         302 Sumner St           NaN  East Boston            MA       02128
# 1              46 ADAMS           NaN   DORCHESTER            MA       02122
# 2      70 BIRCHCROFT RD           NaN    HYDE PARK            MA       02136
# 3   707 NEPONSET STREET           NaN      NORWOOD            MA       02062
# 4  33 MAPLE STREET #206           NaN       MALDEN            MA       02148
#
#      sam_id   latitude  longitude                                  location
# 0  132380.0  42.367678 -71.036580   (42.367678491254956, -71.0365803778755)
# 1     726.0  42.307170 -71.062061  (42.307169528727265, -71.06206056969255)
# 2   15647.0  42.266940 -71.109811    (42.26693960061158, -71.1098107673119)
# 3   52349.0  42.331319 -71.035920    (42.33131949281363, -71.0359204565752)
# 4   15648.0  42.267040 -71.109911   (42.26703959975603, -71.10991076751128)
#
# [5 rows x 25 columns]

# %%
#filter by years intersted
years_interest = ["2024", "2023", "2022", "2021", "2020", "2019", "2018"]

pattern = '|'.join(years_interest)
df_years = df[df['status_dttm'].str.contains(pattern, case=False, na=False)]
display(df_years)
# Out:
#        _id  case_no  ap_case_defn_key          status_dttm  status    code  \
# 709    710  V762114              1013  2024-12-31 10:59:36    Open   102.8
# 710    711  V760019              1013  2024-12-31 10:46:19  Closed   105.1
# 711    712  V807184              1013  2024-12-30 10:19:11  Closed   102.8
# 712    713  V806319              1013  2024-12-26 08:23:23  Closed   105.1
# 713    714  V805052              1013  2024-12-20 13:47:15  Closed   102.8
# ...    ...      ...               ...                  ...     ...     ...
# 6249  6250  V378763              1013  2018-01-03 09:46:38  Closed   105.1
# 6250  6251  V378751              1013  2018-01-03 09:04:18  Closed   105.1
# 6251  6252  V378733              1013  2018-01-03 08:49:54  Closed  1003.6
# 6252  6253  V378660              1013  2018-01-02 15:57:02  Closed   105.1
# 6253  6254  V378579              1013  2018-01-02 10:53:35  Closed   105.1
#
#       value               description violation_stno violation_sthigh  ...  \
# 709     NaN               Maintenance             14              NaN  ...
# 710     NaN  Failure to Obtain Permit            614              NaN  ...
# 711     NaN               Maintenance             51              NaN  ...
# 712     NaN  Failure to Obtain Permit           1162              NaN  ...
# 713     NaN               Maintenance              1                5  ...
# ...     ...                       ...            ...              ...  ...
# 6249    NaN  Failure to Obtain Permit             11              NaN  ...
# 6250    NaN  Failure to Obtain Permit              6              NaN  ...
# 6251    NaN           Means of Egress             58              NaN  ...
# 6252    NaN  Failure to Obtain Permit              8              NaN  ...
# 6253    NaN  Failure to Obtain Permit             58              NaN  ...
#
#      ward                   contact_addr1  contact_addr2  contact_city  \
# 709    18                14 MT CALVARY RD            NaN    ROSLINDALE
# 710    09                    64 Parker St            NaN        Newton
# 711    11                   51 BEECH GLEN            NaN       ROXBURY
# 712    17                  1162 Morton ST            NaN      MATTAPAN
# 713    21  C/O O'BRIENS PUB/GAIL ATKINSON  3 HARVARD AVE        BOSTON
# ...   ...                             ...            ...           ...
# 6249   20                   11 WILLERS ST            NaN  WEST ROXBURY
# 6250   14          C/O MONIQUE NJAMO ENOW  6 MALLON ROAD    DORCHESTER
# 6251   01                   58 TRENTON ST            NaN   EAST BOSTON
# 6252   14                   8 STANWOOD ST            NaN    DORCHESTER
# 6253   01                   58 TRENTON ST            NaN   EAST BOSTON
#
#      contact_state contact_zip    sam_id   latitude  longitude  \
# 709             MA       02131   98107.0  42.280870 -71.113141
# 710             MA       02459   92493.0  42.337200 -71.077451
# 711             MA       02119   13344.0  42.324460 -71.095251
# 712             MA       02126   97659.0  42.275810 -71.073231
# 713             MA       02134  156445.0  42.355261 -71.132901
# ...            ...         ...       ...        ...        ...
# 6249            MA       02132  149770.0  42.259200 -71.150941
# 6250            MA       02121   88816.0  42.302650 -71.073971
# 6251            MA       02128  138380.0  42.378696 -71.037367
# 6252            MA       02121  130309.0  42.310140 -71.081381
# 6253            MA       02128  138380.0  42.378696 -71.037367
#
#                                       location
# 709    (42.28086960340802, -71.11314074390258)
# 710    (42.33719954706552, -71.07745053724503)
# 711    (42.32445957209921, -71.09525060592132)
# 712     (42.27580954746868, -71.0732306647095)
# 713     (42.3552614972918, -71.13290137350627)
# ...                                        ...
# 6249  (42.259199659774055, -71.15094087690251)
# 6250  (42.302649545798204, -71.07397060631675)
# 6251  (42.378696491815774, -71.03736735503051)
# 6252   (42.31013955488775, -71.08138060662927)
# 6253  (42.378696491815774, -71.03736735503051)
#
# [5545 rows x 25 columns]

# %%
#remove columns with contact address - we are only interested in addresses of where the violations occur 

df_new = df.drop(['contact_addr1', 'contact_addr2', "contact_city", "contact_state", "contact_zip", "sam_id", "latitude", "longitude", "location"], axis=1) 

df_new.head()
# Out:
#    _id  case_no  ap_case_defn_key          status_dttm  status   code  value  \
# 0    1   V91983              1013                  NaN  Closed  121.2    NaN
# 1    2  V876069              1013  2025-12-04 15:48:22    Open  102.8    NaN
# 2    3  V876068              1013  2025-12-04 15:27:46    Open  102.8    NaN
# 3    4  V876066              1013  2025-12-04 15:04:58    Open  102.8    NaN
# 4    5  V876048              1013  2025-12-04 14:09:47    Open    116    NaN
#
#             description violation_stno violation_sthigh violation_street  \
# 0  Unsafe and Dangerous            302              NaN           Sumner
# 1           Maintenance             46              NaN            Adams
# 2           Maintenance             70              NaN       Birchcroft
# 3           Maintenance            633              NaN           Eighth
# 4     Unsafe Structures             74              NaN       Birchcroft
#
#   violation_suffix violation_city violation_state violation_zip ward
# 0               ST    East Boston              MA         02128   01
# 1               ST     Dorchester              MA         02122   15
# 2               RD       Mattapan              MA         02136   18
# 3               ST   South Boston              MA         02127   07
# 4               RD       Mattapan              MA         02136   18

# %%
df_new['full_address'] = df_new['violation_stno'].str.cat(df_new['violation_street'], sep=' ').str.cat(df_new['violation_suffix'], sep=' ').str.cat(df_new['violation_city'], sep=' ').str.cat(df_new['violation_zip'], sep=' ')

# %%
df_new = df_new.drop(['violation_stno', 'violation_suffix', 'violation_street', 'violation_city', 'violation_state', 'violation_zip'], axis=1)

df_new.head()
# Out:
#    _id  case_no  ap_case_defn_key          status_dttm  status   code  value  \
# 0    1   V91983              1013                  NaN  Closed  121.2    NaN
# 1    2  V876069              1013  2025-12-04 15:48:22    Open  102.8    NaN
# 2    3  V876068              1013  2025-12-04 15:27:46    Open  102.8    NaN
# 3    4  V876066              1013  2025-12-04 15:04:58    Open  102.8    NaN
# 4    5  V876048              1013  2025-12-04 14:09:47    Open    116    NaN
#
#             description violation_sthigh ward  \
# 0  Unsafe and Dangerous              NaN   01
# 1           Maintenance              NaN   15
# 2           Maintenance              NaN   18
# 3           Maintenance              NaN   07
# 4     Unsafe Structures              NaN   18
#
#                        full_address
# 0   302 Sumner ST East Boston 02128
# 1      46 Adams ST Dorchester 02122
# 2   70 Birchcroft RD Mattapan 02136
# 3  633 Eighth ST South Boston 02127
# 4   74 Birchcroft RD Mattapan 02136

# %%
df_new.to_csv("cleaned_building_and_property_violations.csv", index=False)
